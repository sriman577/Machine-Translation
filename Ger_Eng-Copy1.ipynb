# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array
import pandas as pd
#import os

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)

	return array(cleaned) 

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'fre.txt'
doc = load_doc(filename)
#print(doc)
# split into english-german pairs
pairs = to_pairs(doc)
#temp=array(pairs)
# clean sentences
clean_pairs_ = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs_, 'english-german.pkl')
# spot check
for i in range(100):
	print(clean_pairs_[i,:])
# Out:
# Saved: english-german.pkl
# ['new jersey is sometimes quiet during autumn and it is snowy in april'
#  'new jersey est parfois calme pendant l automne et il est neigeux en avril']
# ['the united states is usually chilly during july and it is usually freezing in november'
#  'les etatsunis est generalement froid en juillet et il gele habituellement en novembre']
# ['california is usually quiet during march and it is usually hot in june'
#  'california est generalement calme en mars et il est generalement chaud en juin']
# ['the united states is sometimes mild during june and it is cold in september'
#  'les etatsunis est parfois legere en juin et il fait froid en septembre']
# ['your least liked fruit is the grape but my least liked is the apple'
#  'votre moins aime fruit est le raisin mais mon moins aime est la pomme']
# ['his favorite fruit is the orange but my favorite is the grape'
#  'son fruit prefere est lorange mais mon prefere est le raisin']
# ['paris is relaxing during december but it is usually chilly in july'
#  'paris est relaxant en decembre mais il est generalement froid en juillet']
# ['new jersey is busy during spring and it is never hot in march'
#  'new jersey est occupe au printemps et il est jamais chaude en mars']
# ['our least liked fruit is the lemon but my least liked is the grape'
#  'notre fruit est moins aime le citron mais mon moins aime est le raisin']
# ['the united states is sometimes busy during january and it is sometimes warm in november'
#  'les etatsunis est parfois occupe en janvier et il est parfois chaud en novembre']
# ['the lime is her least liked fruit but the banana is my least liked'
#  'la chaux est son moins aime des fruits mais la banane est mon moins aime']
# ['he saw a old yellow truck' 'il a vu un vieux camion jaune']
# ['india is rainy during june and it is sometimes warm in november'
#  'inde est pluvieux en juin et il est parfois chaud en novembre']
# ['that cat was my most loved animal'
#  'ce chat etait mon animal le plus aime']
# ['he dislikes grapefruit limes and lemons'
#  'il naime pamplemousse citrons verts et les citrons']
# ['her least liked fruit is the lemon but his least liked is the grapefruit'
#  'son fruit est moins aime le citron mais son moins aime est le pamplemousse']
# ['california is never cold during february but it is sometimes freezing in june'
#  'californie ne fait jamais froid en fevrier mais il est parfois le gel en juin']
# ['china is usually pleasant during autumn and it is usually quiet in october'
#  'chine est generalement agreable en automne et il est generalement calme en octobre']
# ['paris is never freezing during november but it is wonderful in october'
#  'paris est jamais le gel en novembre mais il est merveilleux en octobre']
# ['the united states is never rainy during january but it is sometimes mild in october'
#  'les etatsunis est jamais pluvieux en janvier mais il est parfois doux en octobre']
# ['china is usually pleasant during november and it is never quiet in october'
#  'chine est generalement agreable en novembre et il est jamais tranquille en octobre']
# ['the united states is never nice during february but it is sometimes pleasant in april'
#  'les etatsunis est jamais agreable en fevrier mais il est parfois agreable en avril']
# ['india is never busy during autumn and it is mild in spring'
#  'l inde est jamais occupe a lautomne et il est doux au printemps']
# ['paris is mild during summer but it is usually busy in april'
#  'paris est doux pendant l ete mais il est generalement occupe en avril']
# ['france is never cold during september and it is snowy in october'
#  'france ne fait jamais froid en septembre et il est neigeux en octobre']
# ['california is never cold during may and it is sometimes chilly in march'
#  'californie ne fait jamais froid au mois de mai et il est parfois frisquet en mars']
# ['he dislikes lemons grapes and mangoes'
#  'il deteste les citrons les raisins et les mangues']
# ['their favorite fruit is the mango but our favorite is the pear'
#  'leur fruit prefere est la mangue mais notre prefere est la poire']
# ['france is sometimes quiet during may and it is never chilly in august'
#  'la france est parfois calme au mois de mai et il est jamais froid en aout']
# ['paris is never pleasant during september and it is beautiful in autumn'
#  'paris est jamais agreable en septembre et il est beau a l automne']
# ['he dislikes apples peaches and grapes'
#  'il deteste les pommes les peches et les raisins']
# ['california is usually freezing during december and it is busy in april'
#  'la californie est le gel habituellement en decembre et il est occupe en avril']
# ['your most feared animal is that shark'
#  'votre animal le plus redoute est que le requin']
# ['paris is usually wet during august and it is never dry in november'
#  'paris est generalement humide au mois d aout et il est jamais sec en novembre']
# ['paris is usually beautiful during september and it is usually snowy in november'
#  'paris est generalement beau en septembre et il est generalement enneigee en novembre']
# ['the united states is never wet during january but it is usually hot in october'
#  'les etatsunis est jamais humide en janvier mais il est generalement chaud en octobre']
# ['we like oranges mangoes and grapes'
#  'nous aimons les oranges les mangues et les raisins']
# ['they like pears apples and mangoes'
#  'ils aiment les poires les pommes et les mangues']
# ['she dislikes that little red truck' 'elle deteste ce petit camion rouge']
# ['the grapefruit is my most loved fruit but the banana is her most loved'
#  'le pamplemousse est mon fruit le plus cher mais la banane est la plus aimee']
# ['france is snowy during may and it is never busy in autumn'
#  'la france est la neige au mois de mai et il est jamais trop de monde a l automne']
# ['china is usually mild during winter but it is never busy in february'
#  'chine est generalement doux pendant l hiver mais il est jamais occupe en fevrier']
# ['china is never nice during july but it is usually snowy in spring'
#  'chine est jamais agreable en juillet mais il est generalement enneigee au printemps']
# ['california is busy during november but it is rainy in autumn'
#  'californie est occupe au mois de novembre mais il est pluvieux a l automne']
# ['china is warm during spring and it is sometimes cold in february'
#  'chine est chaud au printemps et il est parfois froid en fevrier']
# ['california is usually beautiful during winter but it is never busy in february'
#  'californie est generalement beau pendant l hiver mais il est jamais occupe en fevrier']
# ['france is wonderful during november but it is sometimes hot in september'
#  'france est merveilleux au mois de novembre mais il est parfois chaud en septembre']
# ['india is usually pleasant during november but it is never relaxing in july'
#  'l inde est generalement agreable en novembre mais il est jamais relaxant en juillet']
# ['the united states is never freezing during autumn but it is never busy in june'
#  'les etatsunis ne sont jamais gel pendant l automne mais il est jamais occupe en juin']
# ['paris is sometimes warm during june but it is usually hot in july'
#  'paris est parfois chaud en juin mais il est generalement chaud en juillet']
# ['paris is never hot during summer and it is usually mild in winter'
#  'paris est jamais chaude pendant l ete et il est generalement doux en hiver']
# ['she disliked a rusty yellow car'
#  'elle naimait pas une voiture jaune rouillee']
# ['france is usually quiet during november but it is sometimes warm in february'
#  'la france est generalement calme en novembre mais il est parfois chaud en fevrier']
# ['new jersey is never wet during november and it is mild in august'
#  'new jersey est jamais humide au mois de novembre et il est doux au mois d aout']
# ['we like peaches pears and strawberries'
#  'nous aimons les peches les poires et les fraises']
# ['the orange is her least liked fruit but the grapefruit is their least liked'
#  'lorange est la moins aime des fruits mais le pamplemousse est leur moins aime']
# ['china is never rainy during november and it is quiet in january'
#  'chine est jamais pluvieux en novembre et il est calme en janvier']
# ['china is relaxing during march but it is sometimes snowy in september'
#  'chine est relaxant au mois de mars mais il est parfois enneigee en septembre']
# ['paris is wonderful during march but it is usually pleasant in june'
#  'paris est merveilleux au mois de mars mais il est generalement agreable en juin']
# ['new jersey is chilly during autumn and it is sometimes pleasant in spring'
#  'new jersey est froid au cours de l automne et il est parfois agreable au printemps']
# ['california is never freezing during october but it is usually quiet in june'
#  'la californie est jamais le gel en octobre mais il est generalement calme en juin']
# ['new jersey is freezing during winter but it is sometimes wonderful in january'
#  'new jersey est le gel pendant l hiver mais il est parfois merveilleux en janvier']
# ['i like grapes pears and strawberries'
#  'jaime les raisins les poires et les fraises']
# ['the lemon is my most loved fruit but the strawberry is our most loved'
#  'le citron est mon fruit le plus aime mais la fraise est notre plus aime']
# ['china is usually dry during march but it is nice in november'
#  'chine est generalement sec en mars mais il est agreable en novembre']
# ['paris is pleasant during december but it is never nice in november'
#  'paris est agreable en decembre mais il est jamais agreable en novembre']
# ['china is freezing during july but it is relaxing in january'
#  'chine gele en juillet mais il est relaxant en janvier']
# ['the apple is our least favorite fruit but the orange is her least favorite'
#  'la pomme est notre fruit prefere moins mais lorange est son moins prefere']
# ['he dislikes grapes grapefruit and bananas'
#  'il deteste les raisins le pamplemousse et les bananes']
# ['he dislikes apples mangoes and strawberries'
#  'il deteste les pommes les mangues et les fraises']
# ['china is hot during july but it is never pleasant in january'
#  'chine est chaud en juillet mais il est jamais agreable en janvier']
# ['india is usually dry during april and it is freezing in february'
#  'l inde est generalement sec en avril et il gele en fevrier']
# ['she is going to the united states next summer'
#  'elle va aux etatsunis l ete prochain']
# ['france is sometimes rainy during february and it is usually quiet in spring'
#  'la france est parfois pluvieux en fevrier et il est generalement calme au printemps']
# ['i plan to visit california next may'
#  'je prevois de visiter la californie en mai prochain']
# ['california is never wet during november and it is sometimes pleasant in september'
#  'california est jamais humide en novembre et il est parfois agreable en septembre']
# ['they like lemons limes and grapefruit'
#  'ils aiment les citrons citrons verts et le pamplemousse']
# ['the united states is never beautiful during march and it is usually relaxing in summer'
#  'les etatsunis est jamais belle en mars et il est relaxant habituellement en ete']
# ['elephants were his most feared animals'
#  'les elephants etaient ses animaux les plus redoutes']
# ['the strawberry is their least favorite fruit but the apple is our least favorite'
#  'la fraise est leur fruit prefere moins mais la pomme est notre moins prefere']
# ['they are going to france next june'
#  'ils vont en france en juin prochain']
# ['he likes strawberries oranges and limes'
#  'il aime les fraises les oranges et les citrons verts']
# ['california is never pleasant during winter and it is sometimes wonderful in december'
#  'california est jamais agreable pendant l hiver et il est parfois merveilleux en decembre']
# ['the apple is our least favorite fruit but the mango is their least favorite'
#  'la pomme est notre fruit prefere moins mais la mangue est leur moins preferee']
# ['she likes strawberries oranges and bananas'
#  'elle aime les fraises les oranges et les bananes']
# ['california is beautiful during january and it is pleasant in february'
#  'californie est beau en janvier et il est agreable en fevrier']
# ['they dislike grapes mangoes and limes'
#  'ils naiment pas les raisins mangues et citrons verts']
# ['she dislikes lemons grapes and oranges'
#  'elle deteste les citrons les raisins et les oranges']
# ['our least favorite fruit is the banana but your least favorite is the grape'
#  'notre fruit prefere moins est la banane mais votre moins prefere est le raisin']
# ['california is never cold during december but it is usually warm in may'
#  'californie ne fait jamais froid en decembre mais il est habituellement chaud en mai']
# ['california is never busy during february and it is usually hot in june'
#  'california est jamais occupe en fevrier et il est generalement chaud en juin']
# ['the united states is sometimes beautiful during november and it is never rainy in march'
#  'les etatsunis est parfois belle au mois de novembre et il est jamais pluvieux en mars']
# ['new jersey is sometimes hot during march and it is beautiful in fall'
#  'new jersey est parfois chaud en mars et il est beau a l automne']
# ['the grapefruit is our least favorite fruit but the orange is your least favorite'
#  'le pamplemousse est notre fruit prefere moins mais lorange est votre prefere moins']
# ['i like grapefruit limes and pears'
#  'i comme le pamplemousse citrons verts et les poires']
# ['she dislikes lemons strawberries and grapes'
#  'elle deteste les citrons les fraises et les raisins']
# ['paris is usually chilly during fall but it is sometimes rainy in july'
#  'paris est generalement froid a lautomne mais il est parfois pluvieux en juillet']
# ['she likes mangoes apples and bananas'
#  'elle aime les mangues les pommes et les bananes']
# ['she is driving the old yellow truck'
#  'elle conduit le vieux camion jaune']
# ['we like peaches mangoes and oranges'
#  'nous aimons les peches les mangues et les oranges']

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-german.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[9000:]
# save
save_clean_data(dataset, 'english-german-both.pkl')
save_clean_data(train, 'english-german-train.pkl')
save_clean_data(test, 'english-german-test.pkl')
# Out:
# Saved: english-german-both.pkl
# Saved: english-german-train.pkl
# Saved: english-german-test.pkl

# %%
filename='input.txt'
#doc = load_doc(filename)

# split into english-german pairs
#pairs = to_pairs(doc)
# clean sentences
#clean_pairs_t = clean_pairs(pairs)
# save clean pairs to file
#save_clean_data(clean_pairs_t, 'english-german-temp.pkl')
# spot check
# open the file as read only
file = open(filename, mode='rt', encoding='utf-8')
# read all text
text = file.read()
# close the file
file.close()
text=text.split('\n')  
print(len(text))
del(text[-1])
#for i in range(len(text)):
 #   print(text[i])
temp=[]
#for i in text:
 #   x=i.split()
  #  l.append(x[0])
   # l.append(x[1])
   # temp.append(l)
for i in text:
    l=i.split('-')
    temp.append(l)
# Out:
# 21

# %%
from pickle import load
import pydot
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
#plot_model(model, to_file='model.png', show_shapes=True)    "error(pydot can't import)"
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 199
# English Max Length: 15
# German Vocabulary Size: 315
# German Max Length: 19
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 19, 256)           80640
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 15, 256)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 15, 256)           525312
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 15, 199)           51143
# =================================================================
# Total params: 1,182,407
# Trainable params: 1,182,407
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/30
#  - 46s - loss: 2.9230 - val_loss: 2.0084
#
# Epoch 00001: val_loss improved from inf to 2.00836, saving model to model.h5
# Epoch 2/30
#  - 41s - loss: 1.7200 - val_loss: 1.4510
#
# Epoch 00002: val_loss improved from 2.00836 to 1.45095, saving model to model.h5
# Epoch 3/30
#  - 40s - loss: 1.3351 - val_loss: 1.1611
#
# Epoch 00003: val_loss improved from 1.45095 to 1.16113, saving model to model.h5
# Epoch 4/30
#  - 41s - loss: 1.0876 - val_loss: 0.9697
#
# Epoch 00004: val_loss improved from 1.16113 to 0.96972, saving model to model.h5
# Epoch 5/30
#  - 40s - loss: 0.9109 - val_loss: 0.8746
#
# Epoch 00005: val_loss improved from 0.96972 to 0.87459, saving model to model.h5
# Epoch 6/30
#  - 41s - loss: 0.8315 - val_loss: 0.8117
#
# Epoch 00006: val_loss improved from 0.87459 to 0.81173, saving model to model.h5
# Epoch 7/30
#  - 41s - loss: 0.9092 - val_loss: 0.8084
#
# Epoch 00007: val_loss improved from 0.81173 to 0.80835, saving model to model.h5
# Epoch 8/30
#  - 41s - loss: 0.7610 - val_loss: 0.7424
#
# Epoch 00008: val_loss improved from 0.80835 to 0.74240, saving model to model.h5
# Epoch 9/30
#  - 40s - loss: 0.6982 - val_loss: 0.6790
#
# Epoch 00009: val_loss improved from 0.74240 to 0.67898, saving model to model.h5
# Epoch 10/30
#  - 41s - loss: 0.6941 - val_loss: 1.0374
#
# Epoch 00010: val_loss did not improve from 0.67898
# Epoch 11/30
#  - 41s - loss: 0.6406 - val_loss: 0.5822
#
# Epoch 00011: val_loss improved from 0.67898 to 0.58225, saving model to model.h5
# Epoch 12/30
#  - 41s - loss: 0.5380 - val_loss: 0.5342
#
# Epoch 00012: val_loss improved from 0.58225 to 0.53422, saving model to model.h5
# Epoch 13/30
#  - 41s - loss: 0.5442 - val_loss: 0.4772
#
# Epoch 00013: val_loss improved from 0.53422 to 0.47722, saving model to model.h5
# Epoch 14/30
#  - 40s - loss: 0.4476 - val_loss: 0.4516
#
# Epoch 00014: val_loss improved from 0.47722 to 0.45156, saving model to model.h5
# Epoch 15/30
#  - 40s - loss: 0.3961 - val_loss: 0.3779
#
# Epoch 00015: val_loss improved from 0.45156 to 0.37791, saving model to model.h5
# Epoch 16/30
#  - 40s - loss: 0.3378 - val_loss: 0.3347
#
# Epoch 00016: val_loss improved from 0.37791 to 0.33472, saving model to model.h5
# Epoch 17/30
#  - 41s - loss: 0.3152 - val_loss: 0.3517
#
# Epoch 00017: val_loss did not improve from 0.33472
# Epoch 18/30
#  - 40s - loss: 0.2798 - val_loss: 0.2941
#
# Epoch 00018: val_loss improved from 0.33472 to 0.29407, saving model to model.h5
# Epoch 19/30
#  - 40s - loss: 0.2396 - val_loss: 0.2649
#
# Epoch 00019: val_loss improved from 0.29407 to 0.26489, saving model to model.h5
# Epoch 20/30
#  - 40s - loss: 0.2237 - val_loss: 0.2398
#
# Epoch 00020: val_loss improved from 0.26489 to 0.23978, saving model to model.h5
# Epoch 21/30
#  - 40s - loss: 0.1981 - val_loss: 0.1754
#
# Epoch 00021: val_loss improved from 0.23978 to 0.17535, saving model to model.h5
# Epoch 22/30
#  - 41s - loss: 0.1384 - val_loss: 0.1473
#
# Epoch 00022: val_loss improved from 0.17535 to 0.14734, saving model to model.h5
# Epoch 23/30
#  - 41s - loss: 0.1092 - val_loss: 0.1204
#
# Epoch 00023: val_loss improved from 0.14734 to 0.12043, saving model to model.h5
# Epoch 24/30
#  - 41s - loss: 0.0866 - val_loss: 0.1032
#
# Epoch 00024: val_loss improved from 0.12043 to 0.10321, saving model to model.h5
# Epoch 25/30
#  - 41s - loss: 0.0727 - val_loss: 0.0935
#
# Epoch 00025: val_loss improved from 0.10321 to 0.09346, saving model to model.h5
# Epoch 26/30
#  - 40s - loss: 0.0631 - val_loss: 0.0857
#
# Epoch 00026: val_loss improved from 0.09346 to 0.08574, saving model to model.h5
# Epoch 27/30
#  - 40s - loss: 0.0568 - val_loss: 0.0853
#
# Epoch 00027: val_loss improved from 0.08574 to 0.08527, saving model to model.h5
# Epoch 28/30
#  - 41s - loss: 0.0533 - val_loss: 0.0801
#
# Epoch 00028: val_loss improved from 0.08527 to 0.08011, saving model to model.h5
# Epoch 29/30
#  - 41s - loss: 0.0483 - val_loss: 0.0821
#
# Epoch 00029: val_loss did not improve from 0.08011
# Epoch 30/30
#  - 41s - loss: 0.0456 - val_loss: 0.0745
#
# Epoch 00030: val_loss improved from 0.08011 to 0.07446, saving model to model.h5

# %%
from pickle import load
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append(raw_target.split())
		predicted.append(translation.split())
	#calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')
test_t=load_clean_sentences('english-german-test-t.pkl')
#test_t=load_clean_sentences('english-german-test-t.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

#our input
# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('trainX')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# [['the peach is their least favorite fruit but the orange is his least favorite'
#   'la peche est leur fruit prefere moins mais lorange est son moins prefere']
#  ['his favorite fruit is the pear but her favorite is the lime'
#   'son fruit prefere est la poire mais son prefere est la chaux']
#  ['the orange is our least liked fruit but the apple is her least liked'
#   'lorange est notre fruit moins aime mais la pomme elle est moins aime']
#  ...
#  ['new jersey is snowy during march but it is sometimes wonderful in november'
#   'new jersey est la neige en mars mais il est parfois merveilleux en novembre']
#  ['california is usually chilly during spring but it is wonderful in march'
#   'californie est generalement froid au printemps mais il est merveilleux en mars']
#  ['new jersey is sometimes wonderful during march but it is sometimes rainy in june'
#   'new jersey est parfois merveilleux au mois de mars mais il est parfois pluvieux en juin']]
# src=[la peche est leur fruit prefere moins mais lorange est son moins prefere], target=[the peach is their least favorite fruit but the orange is his least favorite], predicted=[the peach is their least favorite fruit but the orange is her least favorite]
# src=[son fruit prefere est la poire mais son prefere est la chaux], target=[his favorite fruit is the pear but her favorite is the lime], predicted=[her favorite fruit is the pear but her favorite is the lime]
# src=[lorange est notre fruit moins aime mais la pomme elle est moins aime], target=[the orange is our least liked fruit but the apple is her least liked], predicted=[the orange is our least liked fruit but the apple is her least liked]
# src=[la france est relaxant habituellement pendant l hiver mais il est generalement doux en juillet], target=[france is usually relaxing during winter but it is usually mild in july], predicted=[france is usually relaxing during winter but it is usually mild in july]
# src=[new jersey est generalement pluvieux en juillet mais il est generalement sec en hiver], target=[new jersey is usually rainy during july but it is usually dry in winter], predicted=[new jersey is usually rainy during july but it is usually dry in winter]
# src=[paris est generalement froid pendant l automne et il est doux a l automne], target=[paris is usually cold during fall and it is mild in autumn], predicted=[paris is usually cold during autumn and it is mild in autumn]
# src=[il envisage de se rendre aux etatsunis en juillet], target=[he plans to visit the united states in july], predicted=[he plans to visit the united states in july]
# src=[la peche est moins son fruit prefere mais lorange est votre prefere moins], target=[the peach is her least favorite fruit but the orange is your least favorite], predicted=[the peach is her least favorite fruit but the orange is your least favorite]
# src=[new jersey est parfois agreable au cours de l automne mais il est generalement chaud en juin], target=[new jersey is sometimes pleasant during fall but it is usually warm in june], predicted=[new jersey is sometimes nice during autumn but it is usually hot in june]
# src=[la france est froid en octobre et il est generalement humide en aout], target=[france is chilly during october and it is usually wet in august], predicted=[france is chilly during october and it is usually wet in august]
# C:\Users\srinivas\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-1: 0.002897
# BLEU-2: 0.053825
# BLEU-3: 0.173217
# BLEU-4: 0.232002
# trainX
# src=[la france est jamais calme en juillet et il gele habituellement en hiver], target=[france is never quiet during july and it is usually freezing in winter], predicted=[france is never quiet during july and it is usually freezing in winter]
# src=[la fraise est son fruit prefere moins mais lorange est notre moins prefere], target=[the strawberry is his least favorite fruit but the orange is our least favorite], predicted=[the strawberry is his least favorite fruit but the orange is our least favorite]
# src=[chine est jamais agreable en ete mais il est generalement chaud en octobre], target=[china is never nice during summer but it is usually hot in october], predicted=[china is never nice during summer but it is usually hot in october]
# src=[nous detestons les bananes et les citrons verts], target=[we dislike bananas and limes], predicted=[we dislike bananas and limes]
# src=[l inde est agreable a lautomne mais il est jamais froid en juin], target=[india is pleasant during autumn but it is never chilly in june], predicted=[india is pleasant during fall but it is never chilly in june]
# src=[votre fruit prefere est la fraise mais notre prefere est la banane], target=[your favorite fruit is the strawberry but our favorite is the banana], predicted=[your favorite fruit is the strawberry but our favorite is the banana]
# src=[californie est generalement occupe en juin mais jamais doux en janvier], target=[california is usually busy during june but it is never mild in january], predicted=[california is usually hot during june but it is never mild in january]
# src=[elle est allee en aout dernier en californie], target=[she went to california last august], predicted=[she went to california california august]
# src=[la peche est la moins aime des fruits mais la pomme est son moins aime], target=[the peach is her least liked fruit but the apple is his least liked], predicted=[the peach is her least liked fruit but the apple is his least liked]
# src=[mon fruit prefere est la peche mais votre favori est la poire], target=[my favorite fruit is the peach but your favorite is the pear], predicted=[my favorite fruit is the peach but your favorite is the pear]
# BLEU-1: 0.002663
# BLEU-2: 0.051603
# BLEU-3: 0.168891
# BLEU-4: 0.227163

# %%
def predict_sequence(model, tokenizer, source):
    prediction = model.predict(source, verbose=0)[0]
    integers = [argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
    target.append(word)
    return ' '.join(target)

# %%
def evaluate_model(model, tokenizer, sources, raw_dataset):
    actual, predicted = list(), list()
    predict_sequence(model, eng_tokenizer, sources)
#     for i, source in enumerate(sources):
#         print(i,source)
		# translate encoded source text
		#source = source.reshape((1, source.shape[0]))
   # translation =predict_sequence(model, eng_tokenizer, sources)
		#raw_target, raw_src = raw_dataset[i]
		#if i < 10:
			#print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		#actual.append(raw_target.split())
		#predicted.append(translation.split())
	#calculate BLEU score
	#print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	#print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	#print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	#print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
input1='paris est parfois belle à l automne , mais il est neigeux en juillet'

# %%
evaluate_model(model, eng_tokenizer, input1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-69c8de5cab5f> in <module>()
# ----> 1 evaluate_model1(model, eng_tokenizer, input1)
#
# <ipython-input-133-7728939775d0> in evaluate_model1(model, tokenizer, sources)
#       1 def evaluate_model1(model, tokenizer, sources):
#       2     actual, predicted = list(), list()
# ----> 3     predict_sequence(model, eng_tokenizer, sources)
#       4 #     for i, source in enumerate(sources):
#       5 #         print(i,source)
#
# <ipython-input-132-3a8832fd46c1> in predict_sequence(model, tokenizer, source)
#      37 # generate target given source sequence
#      38 def predict_sequence(model, tokenizer, source):
# ---> 39         prediction = model.predict(source, verbose=0)[0]
#      40         integers = [argmax(vector) for vector in prediction]
#      41         target = list()
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#      90         data = data.values if data.__class__.__name__ == 'DataFrame' else data
#      91         data = [data]
# ---> 92     data = [standardize_single_array(x) for x in data]
#      93
#      94     if len(data) != len(names):
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_utils.py in <listcomp>(.0)
#      90         data = data.values if data.__class__.__name__ == 'DataFrame' else data
#      91         data = [data]
# ---> 92     data = [standardize_single_array(x) for x in data]
#      93
#      94     if len(data) != len(names):
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_utils.py in standardize_single_array(x)
#      25                 'Got tensor with shape: %s' % str(shape))
#      26         return x
# ---> 27     elif x.ndim == 1:
#      28         x = np.expand_dims(x, 1)
#      29     return x
#
# AttributeError: 'str' object has no attribute 'ndim'
